# %%
# Import dependencies
import datetime as dt
import numpy as np
import pandas as pd
import os
import json

#Import the stored  functions file
import stored_functions

#sqlqlchemy libs
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, desc

#Plotly libs
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go

from flask import Flask, render_template, jsonify, redirect
from flask_sqlalchemy import SQLAlchemy
from werkzeug.wrappers import Request, Response

# %%
app = Flask(__name__)
app.debug = True

#Define each Flask route
@app.route("/")
def welcome():
    return render_template('index.html')
    
@app.route("/samples/<sample>")
def samplepick(sample):

    pie_chart = stored_functions.pie_chart_data(sample)

    bubble_chart = stored_functions.bubble_chart_data(sample)

    chart_dict = {'pie':{pie_chart}, 'bubble': {bubble_chart}}

    return(chart_dict)

    

@app.route("/buttons")
def buttons():
    engine = create_engine("sqlite:///db/bellybutton.sqlite")

    Base = automap_base()
    
    Base.prepare(engine, reflect=True)
    Samples_metadata = Base.classes.sample_metadata

    # Create our session (link) from Python to the DB
    session = Session(engine)

    sql_stmt2 = session.query(Samples_metadata).statement
    metadata_df = pd.read_sql_query(sql_stmt2, session.bind)

    #populate the bellybutton dropdown list
    buttons = metadata_df['sample'].tolist()

    return (jsonify(buttons))

#if __name__ == "__main__":
 #   from werkzeug.serving import run_simple
   # run_simple('localhost', 9000, app)

# %%
sample = '950'

pie_chart = stored_functions.pie_chart_data(sample)

bubble_chart = stored_functions.bubble_chart_data(sample)

meta_dict = stored_functions.get_metatdata(sample)

chart_dict = {'pie': pie_chart, 'bubble': bubble_chart, 'meta':meta_dict}


chart_dict
# Out:
# {'pie': {'labels': ['Staphylococcus',
#    'Corynebacterium',
#    'Bacillales',
#    'Actinomycetales',
#    'Aquabacterium',
#    'Streptococcus',
#    'Pasteurellaceae',
#    'Acinetobacter',
#    'Bacilli',
#    'Gemella'],
#   'values': [433.0, 137.0, 24.0, 17.0, 13.0, 13.0, 8.0, 7.0, 7.0, 7.0],
#   'type': 'pie'},
#  'bubble': {'data': [{'x': ['Acinetobacter',
#      'Actinomycetales',
#      'Alphaproteobacteria',
#      'Anaerococcus',
#      'Aquabacterium',
#      'Bacillales',
#      'Bacilli',
#      'Bacteroidetes',
#      'Bosea',
#      'Bradyrhizobiaceae',
#      'Burkholderiales_incertae_sedis',
#      'Caulobacter',
#      'Corynebacterium',
#      'Fusobacterium',
#      'Gemella',
#      'Leptotrichia',
#      'Neisseria',
#      'Pasteurellaceae',
#      'Peptoniphilus',
#      'Prevotella',
#      'Pseudomonas',
#      'Rhodocyclaceae',
#      'Rothia',
#      'Staphylococcaceae',
#      'Staphylococcus',
#      'Streptococcus',
#      'Streptophyta',
#      'Tumebacillus',
#      'Xanthomonadaceae',
#      'Zoogloea'],
#     'y': [7.0,
#      17.0,
#      2.0,
#      5.0,
#      13.0,
#      24.0,
#      7.0,
#      2.0,
#      4.0,
#      3.0,
#      3.0,
#      4.0,
#      137.0,
#      6.0,
#      7.0,
#      3.0,
#      4.0,
#      8.0,
#      4.0,
#      3.0,
#      5.0,
#      4.0,
#      2.0,
#      4.0,
#      433.0,
#      13.0,
#      4.0,
#      2.0,
#      2.0,
#      5.0],
#     'mode': 'markers',
#     'marker': {'color': [7.0,
#       17.0,
#       2.0,
#       5.0,
#       13.0,
#       24.0,
#       7.0,
#       2.0,
#       4.0,
#       3.0,
#       3.0,
#       4.0,
#       137.0,
#       6.0,
#       7.0,
#       3.0,
#       4.0,
#       8.0,
#       4.0,
#       3.0,
#       5.0,
#       4.0,
#       2.0,
#       4.0,
#       433.0,
#       13.0,
#       4.0,
#       2.0,
#       2.0,
#       5.0],
#      'sizemode': 'area',
#      'sizeref': 0.54125,
#      'size': [7.0,
#       17.0,
#       2.0,
#       5.0,
#       13.0,
#       24.0,
#       7.0,
#       2.0,
#       4.0,
#       3.0,
#       3.0,
#       4.0,
#       137.0,
#       6.0,
#       7.0,
#       3.0,
#       4.0,
#       8.0,
#       4.0,
#       3.0,
#       5.0,
#       4.0,
#       2.0,
#       4.0,
#       433.0,
#       13.0,
#       4.0,
#       2.0,
#       2.0,
#       5.0],
#      'symbol': 'circle'},
#     'text': [['Acinetobacter',
#       'Actinomycetales',
#       'Alphaproteobacteria',
#       'Anaerococcus',
#       'Aquabacterium',
#       'Bacillales',
#       'Bacilli',
#       'Bacteroidetes',
#       'Bosea',
#       'Bradyrhizobiaceae',
#       'Burkholderiales_incertae_sedis',
#       'Caulobacter',
#       'Corynebacterium',
#       'Fusobacterium',
#       'Gemella',
#       'Leptotrichia',
#       'Neisseria',
#       'Pasteurellaceae',
#       'Peptoniphilus',
#       'Prevotella',
#       'Pseudomonas',
#       'Rhodocyclaceae',
#       'Rothia',
#       'Staphylococcaceae',
#       'Staphylococcus',
#       'Streptococcus',
#       'Streptophyta',
#       'Tumebacillus',
#       'Xanthomonadaceae',
#       'Zoogloea']]}],
#   'layout': {'title': 'Bacteria Counts by OTU',
#    'xaxis': {'tickangle': 45},
#    'yaxis': {'title': 'Bacteria Count'}}}}
